# %%
import coiled
import dask

import dask.dataframe as dd
# Out:
# /Users/rpelgrim/mambaforge/envs/shuffle/lib/python3.9/site-packages/coiled/cli/install.py:9: FutureWarning: tmpfile is deprecated and will be removed in a future release. Please use dask.utils.tmpfile instead.
#   from distributed.utils import tmpfile

# %%
coiled.create_software_environment(
    name="shuffle",
    pip=[
        "bokeh",
        "pandas",
        "git+https://github.com/gjoseph92/dask@shuffle_service",
        "git+https://github.com/dask/distributed",
    ]
)

# %%
cluster = coiled.Cluster(
    name="shuffle",
    software="shuffle",
    n_workers=10,
    worker_cpu=2,
    worker_memory="4GiB",
)
# Out:
# /Users/rpelgrim/mambaforge/envs/shuffle/lib/python3.9/site-packages/rich/live.py:227: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# Found software environment build
# Created FW rules: coiled-dask-rrpelgr71-54820-firewall
# Created scheduler VM: coiled-dask-rrpelgr71-54820-scheduler (type: t3a.medium, ip: ['3.91.14.142'])
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
from distributed import Client

client = Client(cluster)
client
# Out:
# <Client: 'tls://10.4.11.57:8786' processes=6 threads=12, memory=22.73 GiB>

# %%
df = dask.datasets.timeseries("2000-01-01", "2005-01-01")
dfz = df.assign(z=df.x + df.y)

# %%
dfz.set_index("z", shuffle="service").size.compute()
# Out:
# 631411200

# %%
dfz.head()
# Out:
#                        id      name         x         y         z
# timestamp
# 2000-01-01 00:00:00   981     Kevin -0.943770  0.384912 -0.558858
# 2000-01-01 00:00:01   988   Michael  0.741291  0.669414  1.410706
# 2000-01-01 00:00:02  1033   Norbert -0.057637  0.174817  0.117180
# 2000-01-01 00:00:03  1024     Laura -0.521626  0.381309 -0.140317
# 2000-01-01 00:00:04   990  Patricia -0.348697  0.798404  0.449707
