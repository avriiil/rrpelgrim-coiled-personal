# %%
import dask.dataframe as dd

# %%
# read s3 data into dask dataframe
ddf = dd.read_csv(
    "s3://twitter-saudi-us-east-2/sa_eg_ae_022020_tweets_csv_hashed_*.csv",
    blocksize="64MiB",
    usecols=[
        'tweetid',
        'userid',
        'user_screen_name',
        'follower_count', 
        'following_count',
        'tweet_language',
        'tweet_text',
        'tweet_time', 
        'tweet_client_name', 
        'is_retweet',
        'retweet_userid',
        'retweet_tweetid'],
    engine='python',
    on_bad_lines="warn",
    na_values='None',
    dtype={
        "tweetid": "object",
        "userid": "object",
        "user_screen_name": "object",
        "follower_count": "object",
        "following_count": "object",
        "tweet_language": "object",
        "tweet_text": "object",
        "tweet_time": "object",
        "tweet_client_name": "object",
        "is_retweet": "object",
        "retweet_userid": "object",
        "retweet_tweetid": "object"
    },
    storage_options={
        'key': 'AKIAJQHAXBX32ZCHLAPA', 
        'secret': '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'}
)

# %%
ddf.head()
# Out:
#                tweetid                                      userid  \
# 0  1185949426633924609  2MQmlE42efLqBwlUzJlSkfVEByrmi6Q3bVbj3Hlt4=
# 1  1196674108450385920                          993642585892818944
# 2  1186489444565733376  2MQmlE42efLqBwlUzJlSkfVEByrmi6Q3bVbj3Hlt4=
# 3  1187301099352530944  2MQmlE42efLqBwlUzJlSkfVEByrmi6Q3bVbj3Hlt4=
# 4  1192322251292651520                          993642585892818944
#
#                              user_screen_name follower_count following_count  \
# 0  2MQmlE42efLqBwlUzJlSkfVEByrmi6Q3bVbj3Hlt4=           1422            1616
# 1                                    rahil_76          12576           12682
# 2  2MQmlE42efLqBwlUzJlSkfVEByrmi6Q3bVbj3Hlt4=           1422            1616
# 3  2MQmlE42efLqBwlUzJlSkfVEByrmi6Q3bVbj3Hlt4=           1422            1616
# 4                                    rahil_76          12576           12682
#
#   tweet_language                                         tweet_text  \
# 0            und  RT @daltawater: #كشف_تسربات_المياه\n#كشف_تسربا...
# 1             ar  RT @aljoory120j: #فايز_المالكي\n📍لنشر ودعم حسا...
# 2             ar  RT @Kw_787: .\nٰ\nٰ\nوإني #أحبك على مرأى العال...
# 3             ar  RT @makkha245: متميزون في تفصيل الاثاث المنزلي...
# 4             ar  RT @2whood: ساعة باتيك فيليب رجالي c\n\nالتوصي...
#
#          tweet_time    tweet_client_name is_retweet retweet_userid  \
# 0  2019-10-20 16:02   Twitter for iPhone       true            NaN
# 1  2019-11-19 06:18  Twitter for Android       true            NaN
# 2  2019-10-22 03:48  Twitter for Android       true            NaN
# 3  2019-10-24 09:33  Twitter for Android       true            NaN
# 4  2019-11-07 06:05  Twitter for Android       true            NaN
#
#        retweet_tweetid
# 0  1185853959296245760
# 1  1196324752190824448
# 2  1184617361250406402
# 3  1187130162275598337
# 4  1192185729151098882
